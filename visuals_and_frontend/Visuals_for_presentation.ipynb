# %%
#frontend

# %%
import plotly.express as px
import pandas as pd 
from chart_studio.plotly import iplot as py
import plotly.graph_objects as go
import streamlit as st
from PIL import Image

# %%
dfclust=pd.read_csv('dfclustzzz.csv')

# %%
dfclustz=dfclust.groupby('Pos').mean()

# %%
dfclustz.reset_index(inplace=True)

# %%
image = Image.open('NBA_logo.png')

st.image(image, use_column_width=True)

# %%
st.title('Reassigning Modern NBA Positions by Playing Style/Team Role')
st.subheader('Conventional NBA positions no longer reflect what type of player is on the court. The purpose of this project is to redefine NBA roles that better fit the players style and functionality by using K-Means Clustering')

# %%
st.title('Visualizations for Conventional NBA positions')
image2= Image.open('old_basketball.png')
st.image(image2, use_column_width=True)

# %%
st.header('2011-2019 BoxScore Stats by Positions')
label = dfclustz['Pos']
points = dfclustz['PTS']
assists = dfclustz['AST']
rebounds = dfclustz['TRB']
threept = dfclustz['3P%']
blocks = dfclustz['BLK']
steals = dfclustz['STL']
fig = go.Figure()
fig.add_trace(go.Bar(x=label,
                y= points,
                name='Points',
                marker_color='rgb(55, 83, 109)'
                ))
fig.add_trace(go.Bar(x=label,
                y=assists,
                name='Assists',
                marker_color='rgb(26, 118, 255)'
                ))
fig.add_trace(go.Bar(x=label,
                y=rebounds,
                name='Rebounds',
                marker_color='rgb(100, 50, 300)'
                ))
fig.add_trace(go.Bar(x=label,
                y=threept,
                name='ThreePt %',
                marker_color='rgb(400, 5, 60)'
                ))
fig.add_trace(go.Bar(x=label,
                y=blocks,
                name='Blocks',
                marker_color='rgb(150, 160, 200)'
                ))
fig.add_trace(go.Bar(x=label,
                y=steals,
                name='Steals',
                marker_color='rgb(40, 250, 100)'
                ))
fig.update_layout(
    title='2011-2019 BoxScore Stats by Conventional Positions',
    xaxis_tickfont_size= 10,
    yaxis=dict(
        title='Average',
        titlefont_size=16,
        tickfont_size=14,
    ),
    xaxis=dict(
        title='Positions'
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
st.write(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="11b3ba81-bced-4fd9-be50-a99c602c2e5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11b3ba81-bced-4fd9-be50-a99c602c2e5b")) {
#                     Plotly.newPlot(
#                         '11b3ba81-bced-4fd9-be50-a99c602c2e5b',
#                         [{"marker": {"color": "rgb(55, 83, 109)"}, "name": "Points", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [20.06006051437217, 20.199999999999992, 20.50435931307791, 18.964254062038407, 21.01486146095717]}, {"marker": {"color": "rgb(26, 118, 255)"}, "name": "Assists", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [2.8187594553706545, 2.938472032742157, 8.49669749009246, 3.3153618906942417, 4.353400503778339]}, {"marker": {"color": "rgb(100, 50, 300)"}, "name": "Rebounds", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [14.62768532526474, 11.725648021828118, 5.526816380449136, 7.808271787296897, 5.791939546599501]}, {"marker": {"color": "rgb(400, 5, 60)"}, "name": "ThreePt %", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [0.14365355521936454, 0.2563656207366983, 0.3330052840158523, 0.3371462333825702, 0.3533463476070527]}, {"marker": {"color": "rgb(150, 160, 200)"}, "name": "Blocks", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [2.234493192133129, 1.274215552523874, 0.3850726552179662, 0.7816838995568692, 0.5124685138539051]}, {"marker": {"color": "rgb(40, 250, 100)"}, "name": "Steals", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [1.3344931921331322, 1.3976807639836284, 1.8550858652575992, 1.658345642540621, 1.6197732997481125]}],
#                         {"bargap": 0.15, "bargroupgap": 0.1, "barmode": "group", "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"c ...

# %%
dfclustR=pd.read_csv('dfRolezzz.csv')

# %%
dfclustzr=dfclustR.groupby('Role').mean()

# %%
dfclustzr.reset_index(inplace=True)

# %%
st.header('2011-2019 Leaguewide Conventional Position Percentages')
labels = dfclustR.Pos.unique()
values = dfclustR['Pos'].value_counts(normalize=False)

fig5 = go.Figure(data =[go.Pie(labels=labels, values=values)])
fig5.update_layout(
    title='2011-2019 Leaguewide Conventional Position Percentages',
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
st.write(fig5)
fig5.show()
# Out:
# <div>
#
#
#             <div id="723947b1-59b5-4a62-b991-63309930a813" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("723947b1-59b5-4a62-b991-63309930a813")) {
#                     Plotly.newPlot(
#                         '723947b1-59b5-4a62-b991-63309930a813',
#                         [{"labels": ["SG", "PG", "C", "PF", "SF"], "type": "pie", "values": [794, 757, 733, 677, 661]}],
#                         {"bargap": 0.15, "bargroupgap": 0.1, "barmode": "group", "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"c ...

# %%
dfpospca=pd.read_csv('dfpospcazzz.csv')

# %%
st.header('2011-2019 Conventional NBA position clusters ')
fig2 = px.scatter_3d(dfpospca, x='PC 1', y='PC 2', z='PC 3', color='Pos', title='2011-2019 Conventional NBA Position Clusters'
              )
st.write(fig2)
fig2.show()
# Out:
# <div>
#
#
#             <div id="af5e04f5-63fa-412a-a2ef-0a145c1b0816" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("af5e04f5-63fa-412a-a2ef-0a145c1b0816")) {
#                     Plotly.newPlot(
#                         'af5e04f5-63fa-412a-a2ef-0a145c1b0816',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Pos=SG<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}", "legendgroup": "Pos=SG", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Pos=SG", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-17.837450461003858, 1.7092841732527106, 1.8578413303787635, -3.4943861312628326, -0.8018466492242158, 1.6343613212189605, 20.408061685302812, 0.8136162874777342, -1.1711591994700572, -6.036632556249624, 7.622132458339879, 4.432282466049228, 25.741781760988026, -9.794165373338137, -9.794165373338137, -9.794165373338137, -10.93641551429485, 6.893017447934527, -16.884187794413062, 5.2025948010446665, -8.662747070198778, -8.446796310114502, -8.446796310114502, -8.446796310114502, -1.2997436967640887, -1.2997436967640887, -1.2997436967640887, -1.2997436967640887, 11.380295613727704, -2.5284898096056136, -5.04806868182137, 16.256095483546385, -10.086048894671157, -10.174206378056097, -2.0185342272726867, -5.828570696925682, -7.054652337374282, 20.96550514561101, -5.477575640713486, -12.132643701753528, 20.38048351023139, -1.9014278926490855, -1.9014278926490855, -1.9014278926490855, -5.432784028943463, -6.482632685319219, -6.482632685319219, -6.482632685319219, 8.402950145586559, -18.918342190674764, -3.9034850827379466, 3.5546716756890486, -1.9091736060009443, -7.1607869561094475, 2.206219497111713, -16.820390235244545, -9.297999572043832, -3.0347583247119325, 9.199173405694372, 9.199173405694372, 9.199173405694372, 1.0495272438744636, -2.9861557753404835, -13.294425921055137, 12.904657653942065, 13.695232718501535, -10.006767258525793, -10.006767258525793, -10.006767258525793, -1.4762714031781612, -1.4762714031781612, -1.4762714031781612, -9.486634868381023, 3.749322173806259, -2.7303970214973923, -4.874590103187573, -4.330116107148111, -4.330116107148111, 9.440217555433843, 21.476566917957612, -9.406298267641873, -9.406298267641873, -9.406298267641873, -5.707911840806661, -5.707911840806661, 14.810127831051695, -9.630724739379156, 22.67947442485032, 4.943501965247657, -3.3476930434848087, -7.397253371084437, -9.74363966026046, 15.665422377689152, -0.700202833792416, 5.472732384529143, 3.2507286093322887, -12.775926236616325, -12.775926236616325, -12.775926236616325, 8.541759747927303, -5.936930614894121, -5.936930614894121, -5.936930614894121, -9.170232385143544, -9.170232385143544, -9.170232385143544, -12.266695140562339, -12.266695140562339, -12.266695140562339, -5.6066199385776105, -5.6066199385776105, -10.191268794114707, -5.664138706749438, -5.664138706749438, -5.664138706749438, -1.2656425314124031, -13.982530289215314, -13.982530289215314, -13.982530289215314, 13.56578122630378, 2.583286337616363, 15.428277131501114, -0.2287959861472365, 26.731071514928864, -14.467665424679028, -16.258355436907216, -13.553681354326065, 4.440577380977869, -2.8273872494443832, -11.858483642038625, 3.4380540758398417, 17.525194300903642, -8.713709790315825, 2.191177582497624, 2.191177582497624, 2.191177582497624, -0.2468191790097045, 22.42163213965637, 3.443054588706615, 3.443054588706615, 3.443054588706615, -9.871589092058873, 3.663787682859152, -12.392410344547072, 4.664442014427304, 18.029667646674746, -4.27337617236822, -3.238639288406167, -6.2291983991251385, 13.820833817159974, 13.820833817159974, 13.820833817159974, -12.769591473319318, -2.200268139229578, 5.913428283144975, -7.552153155204031, 24.477774157025557, -2.484324666800203, -4.107597308079677, -5.550802284511667, -18.98870560252901, -5.734931968183293, -6.636758165348803, -2.6443691810233743, 1.6505448168106842, 8.050031796619995, -16.065211331133593, -7.611315308018428, 3.436507499771989, 7.558270460096817, 36.0924922764034, 4.987761109499683, -4.503942001907072, -10.250101228857565, 9.290344476064314, 9.30885944171819, -5.299057839263637, 8.598159982533389, 8.598159982533389, 8.598159982533389, -5.6424425929013085, -4.5941622276966845, 6.0781257604029815, 6.0781257604029815, ...

# %%
st.title('Results After Clustering New Roles')
image3= Image.open('lebron.png')
st.image(image3, use_column_width=True)

# %%
st.header('2011-2019 BoxScore Stats by New Roles')
label = dfclustzr['Role']
points = dfclustzr['PTS']
assists = dfclustzr['AST']
rebounds = dfclustzr['TRB']
threept = dfclustzr['3P%']
blocks = dfclustzr['BLK']
steals = dfclustzr['STL']
fig1 = go.Figure()
fig1.add_trace(go.Bar(x=label,
                y= points,
                name='Points',
                marker_color='rgb(55, 83, 109)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=assists,
                name='Assists',
                marker_color='rgb(26, 118, 255)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=rebounds,
                name='Rebounds',
                marker_color='rgb(100, 50, 300)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=threept,
                name='Threept %',
                marker_color='rgb(400, 5, 60)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=blocks,
                name='Blocks',
                marker_color='rgb(150, 160, 200)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=steals,
                name='Steals',
                marker_color='rgb(40, 250, 100)'
                ))
fig1.update_layout(
    title='2011-2019 BoxScore Stats by New Roles',
    xaxis_tickfont_size= 10,
    yaxis=dict(
        title='Average',
        titlefont_size=16,
        tickfont_size=14,
    ),
    xaxis=dict(
        title='Role'
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
st.write(fig1)
fig1.show()
# Out:
# <div>
#
#
#             <div id="74694b3d-73b7-460a-81bf-0022e7da7806" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("74694b3d-73b7-460a-81bf-0022e7da7806")) {
#                     Plotly.newPlot(
#                         '74694b3d-73b7-460a-81bf-0022e7da7806',
#                         [{"marker": {"color": "rgb(55, 83, 109)"}, "name": "Points", "type": "bar", "x": ["3&D", "All Star", "Backup Inside Big", "Do It All", "Elite Inside Big", "Elite Wing", "Perimeter Scorer", "Star Inside Big", "Superstar"], "y": [19.0791443850267, 25.774153846153837, 14.59607843137255, 22.716891891891883, 20.28086642599277, 21.119999999999987, 14.950087260034916, 25.45529411764707, 34.156862745098046]}, {"marker": {"color": "rgb(26, 118, 255)"}, "name": "Assists", "type": "bar", "x": ["3&D", "All Star", "Backup Inside Big", "Do It All", "Elite Inside Big", "Elite Wing", "Perimeter Scorer", "Star Inside Big", "Superstar"], "y": [4.602887700534764, 6.1415384615384605, 2.687908496732024, 5.386486486486486, 2.7090252707581244, 4.300204081632655, 4.099127399650961, 3.479999999999998, 8.22058823529412]}, {"marker": {"color": "rgb(100, 50, 300)"}, "name": "Rebounds", "type": "bar", "x": ["3&D", "All Star", "Backup Inside Big", "Do It All", "Elite Inside Big", "Elite Wing", "Perimeter Scorer", "Star Inside Big", "Superstar"], "y": [6.828128342245993, 8.405846153846161, 12.858823529411767, 9.867567567567567, 14.629963898916966, 7.192244897959183, 6.369458987783597, 15.320588235294117, 10.485294117647063]}, {"marker": {"color": "rgb(400, 5, 60)"}, "name": "Threept %", "type": "bar", "x": ["3&D", "All Star", "Backup Inside Big", "Do It All", "Elite Inside Big", "Elite Wing", "Perimeter Scorer", "Star Inside Big", "Superstar"], "y": [0.35323208556149804, 0.3768369230769232, 0.038849673202614385, 0.3247229729729728, 0.026541516245487364, 0.3848061224489798, 0.3129860383944151, 0.13716470588235288, 0.3567254901960786]}, {"marker": {"color": "rgb(150, 160, 200)"}, "name": "Blocks", "type": "bar", "x": ["3&D", "All Star", "Backup Inside Big", "Do It All", "Elite Inside Big", "Elite Wing", "Perimeter Scorer", "Star Inside Big", "Superstar"], "y": [0.5952941176470594, 0.9076923076923079, 1.8006535947712436, 1.1150900900900902, 2.083754512635379, 0.6618367346938782, 0.6329842931937179, 2.119999999999999, 1.1401960784313727]}, {"marker": {"color": "rgb(40, 250, 100)"}, "name": "Steals", "type": "bar", "x": ["3&D", "All Star", "Backup Inside Big", "Do It All", "Elite Inside Big", "Elite Wing", "Perimeter Scorer", "Star Inside Big", "Superstar"], "y": [1.5699465240641728, 1.7393846153846149, 1.3882352941176475, 1.7173423423423406, 1.4111913357400712, 1.5751020408163239, 1.5366492146596884, 1.4629411764705877, 2.0323529411764705]}],
#                         {"bargap": 0.15, "bargroupgap": 0.1, "barmode": "group", "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"c ...

# %%
st.header('2011-2019 Leaguewide Player Percentages by Role/Style')
labels = dfclustR.Role.unique()
values = dfclustR['Role'].value_counts(normalize=False)

fig6 = go.Figure(data =[go.Pie(labels=labels, values=values)])
fig6.update_layout(
    title='2011-2019 Leaguewide Player Percentages by Role/Style',
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
st.write(fig6)
fig6.show()
# Out:
# <div>
#
#
#             <div id="bc30eccb-7442-455d-993d-da97bfc6ecf6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bc30eccb-7442-455d-993d-da97bfc6ecf6")) {
#                     Plotly.newPlot(
#                         'bc30eccb-7442-455d-993d-da97bfc6ecf6',
#                         [{"labels": ["Perimeter Scorer", "Star Inside Big", "Do It All", "Elite Wing", "3&D", "Superstar", "All Star", "Backup Inside Big", "Elite Inside Big"], "type": "pie", "values": [935, 573, 490, 444, 325, 306, 277, 170, 102]}],
#                         {"bargap": 0.15, "bargroupgap": 0.1, "barmode": "group", "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"c ...

# %%
dfclustpca6=pd.read_csv('dfclustpca6.csv')

# %%
st.header('2011-2019 New Clusters by Role/ Playing Style')
fig3 = px.scatter_3d(dfclustpca6, x='PC1', y='PC2', z='PC3', color='Role', title='2011-2019 New Clusters by Role/ Playing Style'
              )
st.write(fig3)
fig3.show()
# Out:
# <div>
#
#
#             <div id="7c68c435-7d98-4bbc-9d1c-7c458e6bd253" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7c68c435-7d98-4bbc-9d1c-7c458e6bd253")) {
#                     Plotly.newPlot(
#                         '7c68c435-7d98-4bbc-9d1c-7c458e6bd253',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Role=Perimeter Scorer<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}", "legendgroup": "Role=Perimeter Scorer", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Role=Perimeter Scorer", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-5.593891444347892, -5.728519140231936, -2.423891861093621, -2.8902158521247334, -4.762167730117497, -1.6503633126274728, -2.0130549337620787, -1.4134051113750066, -2.7212681171114994, -4.115460155971835, -4.115460155971835, -4.115460155971835, -4.294242252287833, -4.107486191442848, -5.4029818216176775, -4.90716969820647, -4.90716969820647, -4.90716969820647, -4.90716969820647, -5.532588330830593, -3.720327322813867, -3.720327322813867, -3.720327322813867, -1.5267567365430603, -1.5267567365430603, -1.5267567365430603, -4.460439034214613, -3.7693293079620473, -4.659499570333909, -2.933264666754788, -3.8231237028543714, -4.181007871257972, -1.5476030376561942, -4.5095131998881754, -5.595662573559379, -1.3315357278358515, -5.030100532604461, -2.9191615181344486, -2.9980430991934988, -2.524223787777073, -1.2283838140090886, -2.521238132760185, -2.521238132760185, -2.521238132760185, -5.797265833138006, -5.797265833138006, -5.797265833138006, -4.191151342705044, -4.191151342705044, -4.191151342705044, -3.071809592821088, -3.252295731416897, -3.252295731416897, -3.252295731416897, -3.8820143581058137, -3.8820143581058137, -3.8820143581058137, -4.067186795509585, -3.8582261633945443, -3.8582261633945443, -3.8582261633945443, -4.595575687205343, -6.1959688811700415, -6.1959688811700415, -6.1959688811700415, -2.7401103477933773, -2.728997287808524, -5.64945354529996, -3.096288142601716, -4.208530981346389, -3.2129285796417344, -3.3376900646777257, -4.560263592675182, -3.4235154404307697, -4.20926837288798, -4.20926837288798, -4.20926837288798, -2.918576523565424, -3.8458220196591983, -3.8458220196591983, -3.8458220196591983, -3.228442831787647, -3.228442831787647, -3.228442831787647, -4.443425918350958, -4.443425918350958, -4.443425918350958, -3.0253477946620557, -3.0253477946620557, -3.0253477946620557, -3.3993229605430533, -3.3993229605430533, -3.3993229605430533, -4.435031949367226, -4.2699699281011165, -0.7664816060994807, -2.2699619933849657, -4.053048310720457, -4.4680126947537, -5.034755350377019, -4.742213394496184, -3.695342439247257, -3.369537242827556, -2.954489806144008, -4.817447095385042, -2.141597000956803, -2.141597000956803, -2.141597000956803, -2.052367994135816, -3.611647419747714, -2.996497051468699, -3.4759392385917445, -2.4990947892985766, -2.6418548668799717, -3.0319181487953726, -3.1567580152724664, -2.166929991657072, -5.386061765823285, -4.380068401798317, -2.2845010946577595, -4.226165246424896, -4.321770661194413, -4.030895415711022, -1.4920840727322051, -3.5186376067208767, -6.086265512061384, -3.344439725087989, -3.801024795387292, 0.1618542487093622, -3.240323888226104, -3.315568483208568, -3.315568483208568, -3.315568483208568, -3.204473989002358, -3.230634086337668, -6.226516369778991, -6.226516369778991, -6.226516369778991, -3.9430020833559762, -2.252234721863267, -4.387405585138517, -2.2338912276383547, -4.891694841161441, -4.880539266704554, -4.880539266704554, -4.880539266704554, -4.765351738307243, -6.041960708793801, -3.183731160901746, -2.943294199772402, -0.1919683349874048, -0.1919683349874048, -0.1919683349874048, -3.1546624928396105, -3.4100323261436034, -4.4656087595279566, -4.277600067996326, -4.310359942149811, -4.310359942149811, -4.310359942149811, -1.842311303524864, -5.583101961289627, -5.160084966248482, -3.4685853433028586, -3.6715862357159086, -1.7042205338791518, -3.2352748091096992, -2.60328952578828, -5.512509389409226, -3.2847912473701406, -4.417546687434903, -4.5190647954085055, -3.9692956591615465, -4.958834455991647, -2.8988668293515407, -2.8988668293515407, -2.8988668293515407, -3.4054806984837853, -3.91935290569412, -3.91935290569412 ...

# %%
st.subheader('What is the difference between Elite teams & Average teams when it comes to player roles/styles?')

# %%
st.subheader('Do winning teams have more or less players with a specific style/role. Does roster diversity play a part in winning? ')

# %%
dfAverage=pd.read_csv('dfAverageee.csv')

# %%
st.header("Roster Construction for various 'Average' NBA Teams over the last 4 years")
labels = dfAverage.Role.unique()
values = dfAverage['Role'].value_counts(normalize=False)

fig8 = go.Figure(data =[go.Pie(labels=labels, values=values)])
fig8.update_layout(
    title="Roster Construction for various 'Average' NBA Teams over the last 4 years",
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
st.write(fig8)
fig8.show()
# Out:
# <div>
#
#
#             <div id="fe8039b4-468e-46ee-b440-8d5ac7709757" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fe8039b4-468e-46ee-b440-8d5ac7709757")) {
#                     Plotly.newPlot(
#                         'fe8039b4-468e-46ee-b440-8d5ac7709757',
#                         [{"labels": ["Elite Wing", "All Star", "Star Inside Big", "Do It All", "Superstar", "Perimeter Scorer", "3&D", "Backup Inside Big"], "type": "pie", "values": [11, 9, 6, 5, 3, 2, 1, 1]}],
#                         {"bargap": 0.15, "bargroupgap": 0.1, "barmode": "group", "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"c ...

# %%
dfFinals=pd.read_csv('dfFinalsss.csv')

# %%
st.header('Roster Construction for NBA Finals Teams over the last 4 years')
labels = dfFinals.Role.unique()
values = dfFinals['Role'].value_counts(normalize=False)

fig7 = go.Figure(data =[go.Pie(labels=labels, values=values)])
fig7.update_layout(
    title='Roster Construction for NBA Finals Teams over the last 4 years',
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
st.write(fig7)
fig7.show()
# Out:
# <div>
#
#
#             <div id="2683e52f-a6bd-4879-96cf-e1d8d56ea173" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2683e52f-a6bd-4879-96cf-e1d8d56ea173")) {
#                     Plotly.newPlot(
#                         '2683e52f-a6bd-4879-96cf-e1d8d56ea173',
#                         [{"labels": ["Superstar", "All Star", "Elite Wing", "3&D", "Backup Inside Big", "Elite Inside Big", "Do It All", "Perimeter Scorer"], "type": "pie", "values": [11, 7, 6, 4, 4, 3, 3, 1]}],
#                         {"bargap": 0.15, "bargroupgap": 0.1, "barmode": "group", "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"c ...

# %%
st.subheader('Main Takeaway: Overall NBA Finalist teams have more star power and their inside players have a reserved/defined role. In comparison, average NBA teams have less star power and rely on star inside bigs as their focal points.')

# %%
label = dfclustzr['Role']
points = dfclustzr['PTS']
assists = dfclustzr['AST']
rebounds = dfclustzr['TRB']
threept = dfclustzr['3P%']
blocks = dfclustzr['BLK']
steals = dfclustzr['STL']
fig1 = go.Figure()
fig1.add_trace(go.Bar(x=label,
                y= points,
                name='Points',
                marker_color='rgb(55, 83, 109)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=assists,
                name='Assists',
                marker_color='rgb(26, 118, 255)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=rebounds,
                name='Rebounds',
                marker_color='rgb(100, 50, 300)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=threept,
                name='Threept %',
                marker_color='rgb(400, 5, 60)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=blocks,
                name='Blocks',
                marker_color='rgb(150, 160, 200)'
                ))
fig1.add_trace(go.Bar(x=label,
                y=steals,
                name='Steals',
                marker_color='rgb(40, 250, 100)'
                ))
fig1.update_layout(
    title='2011-2019 BoxScore Stats by New Roles',
    xaxis_tickfont_size= 10,
    yaxis=dict(
        title='Average',
        titlefont_size=16,
        tickfont_size=14,
    ),
    xaxis=dict(
        title='Role'
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
st.write(fig1)
fig1.show()

# %%
st.header('Roster Construction for NBA Finals Teams over the last 4 years')
labels = dfFinals.Role.unique()
values = dfFinals['Role'].value_counts(normalize=False)

fig7 = go.Figure()
fig7.add_trace(go.Pie(data =[go.Pie(labels=labels, values=values)])
fig7.update_layout(
    title='Roster Construction for NBA Finals Teams over the last 4 years',
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
st.write(fig7)
fig7.show()
# Out:
# <div>
#
#
#             <div id="34bbb0ec-cc0c-4f18-8763-ac4c5158b687" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("34bbb0ec-cc0c-4f18-8763-ac4c5158b687")) {
#                     Plotly.newPlot(
#                         '34bbb0ec-cc0c-4f18-8763-ac4c5158b687',
#                         [{"labels": ["Superstar", "All Star", "Elite Wing", "3&D", "Backup Inside Big", "Elite Inside Big", "Do It All", "Perimeter Scorer"], "type": "pie", "values": [11, 7, 6, 4, 4, 3, 3, 1]}],
#                         {"bargap": 0.15, "bargroupgap": 0.1, "barmode": "group", "legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"c ...
