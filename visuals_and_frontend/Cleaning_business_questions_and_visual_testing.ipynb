# %% [markdown]
# #### Top

# %%
# Visuals 2

# %%
import plotly.express as px

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline

# Import Sci-Kit Learn
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
dfclusterf=pd.read_csv('finalclusterdata.csv')

# %%
dfclusterf2=pd.read_csv('realfinalclusterdata.csv')

# %%
len(dfclusterf2)
# Out:
# 3622

# %%
dfclusterf.head(20)
# Out:
#                    Player  DRtg   Season   ORtg  USG%  VORP    WS   PER   Age  \
# 0            Álex Abrines   111  2018-19  103.0  12.2  -0.2   0.6   6.3  25.0
# 1            Jaylen Adams   115  2018-19   99.0  13.5  -0.3   0.1   7.6  22.0
# 2            Steven Adams   106  2018-19  120.0  16.4   3.2   9.1  18.5  25.0
# 3             Bam Adebayo   104  2018-19  120.0  15.8   2.4   6.8  17.9  21.0
# 4       LaMarcus Aldridge   110  2018-19  117.0  26.9   2.5   9.3  22.9  33.0
# 5           Grayson Allen   111  2018-19   95.0  24.4  -0.5   0.0   7.5  23.0
# 6           Jarrett Allen   106  2018-19  123.0  15.9   2.4   7.6  18.5  20.0
# 7            Kadeem Allen   114  2018-19  116.0  19.6   0.1   1.0  16.2  26.0
# 8         Al-Farouq Aminu   109  2018-19  118.0  13.7   1.7   5.8  13.2  28.0
# 9         Justin Anderson   113  2018-19  103.0  17.2  -0.1   0.4  11.2  25.0
# 10          Kyle Anderson   107  2018-19  110.0  12.6   1.0   2.7  12.8  25.0
# ...

# %%
# Bar count stat by old position

# %%
dfclusterf.columns
# Out:
# Index(['Player', 'DRtg', 'Season', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Age',
#        'Tm', 'Lg', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA',
#        'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%', 'Year', 'Pos',
#        'Cluster', 'Role'],
#       dtype='object')

# %%
dfclusterf.groupby('Pos').mean()
# Out:
#              DRtg        ORtg       USG%      VORP        WS        PER  \
# Pos
# C      104.303502  107.756809  17.422374  0.813619  3.596952  15.125940
# C-PF   104.437500  103.937500  17.106250  0.331250  2.456250  13.787500
# PF     105.697415  105.352526  19.016569  0.769859  3.443361  14.297709
# PF-C   105.400000  103.100000  16.570000  0.410000  2.280000  12.880000
# PF-SF  108.253165   87.607595  22.125316 -0.198734  0.406329   9.289873
# PG     108.376116  103.235491  20.114732  0.650223  2.908761  13.578962
# PG-SF  104.000000   93.000000  24.100000 -0.100000  1.500000  12.400000
# PG-SG  109.523810  102.142857  19.700000  0.095238  1.814286  12.566667
# SF     107.272100  104.000000  18.753605  0.806959  3.052163  12.798997
# SF-PF  107.916667  102.583333  19.066667  0.416667  2.458333  12.491667
# SF-SG  108.944444  104.055556  19.438889  0.705556  2.922222  13.055556
# SG     108.516070  104.516070  19.806913  0.651183  2.920861  12.946089
# ...

# %%
dfclusterf.Pos.value_counts()
# Out:
# PG       1792
# PF       1702
# SG       1649
# SF       1595
# C        1542
# PF-SF      79
# PG-SG      21
# SF-SG      18
# C-PF       16
# SG-SF      14
# SG-PG      14
# SF-PF      12
# PF-C       10
# SG-PF       4
# PG-SF       1
# Name: Pos, dtype: int64

# %%
# need to make into just 5 positions 
# can remove - , then keep first 2

# %%
dfclustertest=dfclusterf

# %%
dfclustertest.Pos.value_counts()
# Out:
# PG       1792
# PF       1702
# SG       1649
# SF       1595
# C        1542
# PF-SF      79
# PG-SG      21
# SF-SG      18
# C-PF       16
# SG-SF      14
# SG-PG      14
# SF-PF      12
# PF-C       10
# SG-PF       4
# PG-SF       1
# Name: Pos, dtype: int64

# %%
df2=pd.DataFrame(df2)

# %%
df2.Pos.value_counts()
# Out:
# PG      1792
# PF      1702
# SG      1649
# SF      1595
# C       1542
# PFSF      79
# PGSG      21
# SFSG      18
# CPF       16
# SGPG      14
# SGSF      14
# SFPF      12
# PFC       10
# SGPF       4
# PGSF       1
# Name: Pos, dtype: int64

# %%
dfclustertest['Pos'].str[:2]
# Out:
# 0       SG
# 1       PG
# 2        C
# 3        C
# 4        C
# 5       SG
# 6        C
# 7       SG
# 8       PF
# 9       SF
# 10      SF
# 11      PF
# 12      SF
# 13      PG
# 14      SF
# 15      SF
# 16      SF
# 17      PG
# 18       C
# 19      SG
# 20      PF
# 21      PG
# 22       C
# 23      PG
# 24      PF
# 25      PF
# 26      SF
# 27      SG
# 28      SF
# 29      SF
#         ..
# 8439    PF
# 8440     C
# 8441    SF
# 8442    PF
# 8443    PG
# 8444    PF
# 8445    PF
# 8446    SF
# 8447    SG
# 8448     C
# 8449    PG
# 8450    PF
# 8451    SG
# 8452    SF
# 8453    PG
# 8454    PF
# 8455    PF
# 8456    PF
# 8457    SF
# 8458     C
# 8459    PG
# 8460    SF
# 8461    SF
# 8462    SF
# 8463    SF
# 8464     C
# 8465     C
# 8466     C
# 8467    SF
# 8468     C
# Name: Pos, Length: 8469, dtype: object

# %%
df3=pd.DataFrame(df3)

# %%
dfclustertest.Pos.value_counts()
# Out:
# PG       1792
# PF       1702
# SG       1649
# SF       1595
# C        1542
# PF-SF      79
# PG-SG      21
# SF-SG      18
# C-PF       16
# SG-SF      14
# SG-PG      14
# SF-PF      12
# PF-C       10
# SG-PF       4
# PG-SF       1
# Name: Pos, dtype: int64

# %%
len(df3)
# Out:
# 8469

# %%
len(dfclusterf)
# Out:
# 8469

# %%
dfclusterf2.Pos.value_counts()
# Out:
# SG       782
# PG       751
# PF       726
# SF       670
# C        659
# SG-PG      6
# PG-SG      6
# SG-SF      5
# SF-SG      5
# PF-SF      5
# C-PF       2
# PF-C       2
# SF-PF      2
# SG-PF      1
# Name: Pos, dtype: int64

# %%
dfclusterf2

# %%
dfclusterz.Pos.value_counts()
# Out:
# SG       782
# PG       751
# PF       726
# SF       670
# C        659
# SG-PG      6
# PG-SG      6
# SG-SF      5
# SF-SG      5
# PF-SF      5
# C-PF       2
# PF-C       2
# SF-PF      2
# SG-PF      1
# Name: Pos, dtype: int64

# %%
dfclusterz.loc[dfclusterz.Pos=='PF-SF', ["Pos"]] = 'PF'

# %%
dfclusterz.loc[dfclusterz.Pos=='PG-SG', ['Pos']]='PG'

# %%
dfclusterz.loc[dfclusterz.Pos=='SF-SG', ['Pos']]='SF'

# %%
dfclusterz.loc[dfclusterz.Pos=='C-PF', ['Pos']]='C'

# %%
dfclusterz.loc[dfclusterz.Pos=='SG-SF', ['Pos']]='SG'

# %%
dfclusterz.loc[dfclusterz.Pos=='SG-PG', ['Pos']]='SG'

# %%
dfclusterz.loc[dfclusterz.Pos=='SF-PF', ['Pos']]='SF'

# %%
dfclusterz.loc[dfclusterz.Pos=='PF-C', ['Pos']]='PF'

# %%
dfclusterz.loc[dfclusterz.Pos=='SG-PF', ['Pos']]='SG'

# %%
#dfclusterf2.loc[dfclusterf2.Pos=='PG-SF', ['Pos']]='PG'

# %%
dfclusterz.Pos.value_counts()
# Out:
# SG    794
# PG    757
# PF    733
# SF    677
# C     661
# Name: Pos, dtype: int64

# %%
len(dfclusterf2)
# Out:
# 3622

# %%
len(dfclustertest)
# Out:
# 8469

# %%
dfclusterf2.to_csv('masterfinalmoderndata.csv', index=False)

# %%
dfclustertest.to_csv('finalclusterdata2.csv', index=False)

# %%
dfclustertest.head()
# Out:
#               Player  DRtg   Season   ORtg  USG%  VORP   WS   PER   Age   Tm  \
# 0       Álex Abrines   111  2018-19  103.0  12.2  -0.2  0.6   6.3  25.0  OKC
# 1       Jaylen Adams   115  2018-19   99.0  13.5  -0.3  0.1   7.6  22.0  ATL
# 2       Steven Adams   106  2018-19  120.0  16.4   3.2  9.1  18.5  25.0  OKC
# 3        Bam Adebayo   104  2018-19  120.0  15.8   2.4  6.8  17.9  21.0  MIA
# 4  LaMarcus Aldridge   110  2018-19  117.0  26.9   2.5  9.3  22.9  33.0  SAS
#
#    ...    FG%    2P%    3P%   eFG%    FT%    TS%  Year  Pos  Cluster  \
# 0  ...  0.357  0.500  0.323  0.487  0.923  0.507  2018   SG      5.0
# 1  ...  0.345  0.361  0.338  0.459  0.778  0.474  2018   PG      5.0
# 2  ...  0.595  0.596  0.000  0.595  0.500  0.591  2018    C      6.0
# 3  ...  0.576  0.588  0.200  0.579  0.735  0.623  2018    C      6.0
# 4  ...  0.519  0.528  0.238  0.522  0.847  0.576  2018    C      6.0
#
#                Role
# 0  Perimeter Scorer
# 1  Perimeter Scorer
# 2   Star Inside Big
# ...

# %%
# Bar count stat by old position (Can now try)

# %%
dfclust=dfclustertest

# %%
dfclust['Pos2'] = dfclust['Pos']

# %%
dfclust.groupby('Pos2').mean()
# Out:
#             DRtg        ORtg       USG%      VORP        WS        PER  \
# Pos2
# C     104.304878  107.717587  17.419127  0.808665  3.585237  15.112195
# PF    105.808487  104.557231  19.140034  0.725126  3.302903  14.068900
# PG    108.386990  103.217200  20.112128  0.643385  2.895314  13.566593
# SF    107.295385  103.990154  18.763508  0.802954  3.046338  12.799569
# SG    108.526472  104.487805  19.785842  0.641761  2.907912  12.926353
#
#             Age          G         GS           MP  ...        PF        PTS  \
# Pos2                                                ...
# C     27.134146  63.678434  34.183569  1406.911425  ...  6.300257  18.643774
# PF    26.533780  64.052485  29.707984  1507.484645  ...  5.228811  19.978950
# PG    26.983462  62.528115  29.979052  1535.348401  ...  4.032911  19.875083
# SF    26.556308  64.059692  32.958154  1609.672000  ...  4.296677  19.787385
# SG    26.937537  64.685306  30.757287  1626.097561  ...  3.965556  21.018858
#
# ...

# %%
fig = px.bar(dfclust, x="", y="3P%")
fig.show()

# %%
dfclust.columns
# Out:
# Index(['Player', 'DRtg', 'Season', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Age',
#        'Tm', 'Lg', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA',
#        'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%', 'Year', 'Pos',
#        'Cluster', 'Role', 'Pos2'],
#       dtype='object')

# %%
import plotly.graph_objects as go

# %%
Positions=['PG', 'SG', 'SF','PF', 'C']
data= dfclust
fig = go.Figure(data=[
    go.Bar(name='PTS', x=Positions, y=[500]),
    go.Bar(name='AST', x=Positions, y=[400])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
# Out:
# <div>
#
#
#             <div id="9c13f629-bffe-4af1-857f-7ced1997e3e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c13f629-bffe-4af1-857f-7ced1997e3e0")) {
#                     Plotly.newPlot(
#                         '9c13f629-bffe-4af1-857f-7ced1997e3e0',
#                         [{"name": "PTS", "type": "bar", "x": ["PG", "SG", "SF", "PF", "C"], "y": [500]}, {"name": "AST", "type": "bar", "x": ["PG", "SG", "SF", "PF", "C"], "y": [400]}],
# ...

# %%
from chart_studio.plotly import iplot as py

# %%
dfclust.head()
# Out:
#               Player  DRtg   Season   ORtg  USG%  VORP   WS   PER   Age   Tm  \
# 0       Álex Abrines   111  2018-19  103.0  12.2  -0.2  0.6   6.3  25.0  OKC
# 1       Jaylen Adams   115  2018-19   99.0  13.5  -0.3  0.1   7.6  22.0  ATL
# 2       Steven Adams   106  2018-19  120.0  16.4   3.2  9.1  18.5  25.0  OKC
# 3        Bam Adebayo   104  2018-19  120.0  15.8   2.4  6.8  17.9  21.0  MIA
# 4  LaMarcus Aldridge   110  2018-19  117.0  26.9   2.5  9.3  22.9  33.0  SAS
#
#    ...    2P%    3P%   eFG%    FT%    TS%  Year  Pos  Cluster  \
# 0  ...  0.500  0.323  0.487  0.923  0.507  2018   SG      5.0
# 1  ...  0.361  0.338  0.459  0.778  0.474  2018   PG      5.0
# 2  ...  0.596  0.000  0.595  0.500  0.591  2018    C      6.0
# 3  ...  0.588  0.200  0.579  0.735  0.623  2018    C      6.0
# 4  ...  0.528  0.238  0.522  0.847  0.576  2018    C      6.0
#
#                Role  Pos2
# 0  Perimeter Scorer    SG
# 1  Perimeter Scorer    PG
# 2   Star Inside Big     C
# ...

# %%
dfclust2=dfclust.groupby('Pos2').mean()

# %%
dfclust2.head()
# Out:
#             DRtg        ORtg       USG%      VORP        WS        PER  \
# Pos2
# C     104.304878  107.717587  17.419127  0.808665  3.585237  15.112195
# PF    105.808487  104.557231  19.140034  0.725126  3.302903  14.068900
# PG    108.386990  103.217200  20.112128  0.643385  2.895314  13.566593
# SF    107.295385  103.990154  18.763508  0.802954  3.046338  12.799569
# SG    108.526472  104.487805  19.785842  0.641761  2.907912  12.926353
#
#             Age          G         GS           MP  ...        PF        PTS  \
# Pos2                                                ...
# C     27.134146  63.678434  34.183569  1406.911425  ...  6.300257  18.643774
# PF    26.533780  64.052485  29.707984  1507.484645  ...  5.228811  19.978950
# PG    26.983462  62.528115  29.979052  1535.348401  ...  4.032911  19.875083
# SF    26.556308  64.059692  32.958154  1609.672000  ...  4.296677  19.787385
# SG    26.937537  64.685306  30.757287  1626.097561  ...  3.965556  21.018858
#
# ...

# %%
dfclust2.columns
# Out:
# Index(['DRtg', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Age', 'G', 'GS', 'MP',
#        'FG', 'FGA', '2P', '2PA', '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'eFG%',
#        'FT%', 'TS%', 'Year', 'Cluster'],
#       dtype='object')

# %%
dfclust.columns
# Out:
# Index(['Player', 'DRtg', 'Season', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Age',
#        'Tm', 'Lg', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA',
#        'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%', 'Year', 'Pos',
#        'Cluster', 'Role', 'Pos2'],
#       dtype='object')

# %%
dfclust3=dfclust2.unstack()

# %%
dfclust2.head()
# Out:
#             DRtg        ORtg       USG%      VORP        WS        PER  \
# Pos2
# C     104.304878  107.717587  17.419127  0.808665  3.585237  15.112195
# PF    105.808487  104.557231  19.140034  0.725126  3.302903  14.068900
# PG    108.386990  103.217200  20.112128  0.643385  2.895314  13.566593
# SF    107.295385  103.990154  18.763508  0.802954  3.046338  12.799569
# SG    108.526472  104.487805  19.785842  0.641761  2.907912  12.926353
#
#             Age          G         GS           MP  ...        PF        PTS  \
# Pos2                                                ...
# C     27.134146  63.678434  34.183569  1406.911425  ...  6.300257  18.643774
# PF    26.533780  64.052485  29.707984  1507.484645  ...  5.228811  19.978950
# PG    26.983462  62.528115  29.979052  1535.348401  ...  4.032911  19.875083
# SF    26.556308  64.059692  32.958154  1609.672000  ...  4.296677  19.787385
# SG    26.937537  64.685306  30.757287  1626.097561  ...  3.965556  21.018858
#
# ...

# %%
dfclust4=dfclust2

# %%
df_2.reset_index(inplace=True)

# %%
dfclust4.reset_index(inplace=True)

# %%
dfclust4.head()
# Out:
#   Pos2        DRtg        ORtg       USG%      VORP        WS        PER  \
# 0    C  104.304878  107.717587  17.419127  0.808665  3.585237  15.112195
# 1   PF  105.808487  104.557231  19.140034  0.725126  3.302903  14.068900
# 2   PG  108.386990  103.217200  20.112128  0.643385  2.895314  13.566593
# 3   SF  107.295385  103.990154  18.763508  0.802954  3.046338  12.799569
# 4   SG  108.526472  104.487805  19.785842  0.641761  2.907912  12.926353
#
#          Age          G         GS  ...        PF        PTS       FG%  \
# 0  27.134146  63.678434  34.183569  ...  6.300257  18.643774  0.506212
# 1  26.533780  64.052485  29.707984  ...  5.228811  19.978950  0.457721
# 2  26.983462  62.528115  29.979052  ...  4.032911  19.875083  0.416434
# 3  26.556308  64.059692  32.958154  ...  4.296677  19.787385  0.432378
# 4  26.937537  64.685306  30.757287  ...  3.965556  21.018858  0.423561
#
#         2P%       3P%      eFG%       FT%       TS%         Year   Cluster
# ...

# %%
label = dfclust4['Pos2']
points = dfclust4['PTS']
assists = dfclust4['AST']
fig = go.Figure()
fig.add_trace(go.Bar(x=label,
                y= points,
                name='Points',
                marker_color='rgb(55, 83, 109)'
                ))
fig.add_trace(go.Bar(x=label,
                y=assists,
                name='Assists',
                marker_color='rgb(26, 118, 255)'
                ))

fig.update_layout(
    title='Points and Assists',
    xaxis_tickfont_size= 10,
    yaxis=dict(
        title='Count',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="23a19862-c53c-491c-b820-c4860143d463" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23a19862-c53c-491c-b820-c4860143d463")) {
#                     Plotly.newPlot(
#                         '23a19862-c53c-491c-b820-c4860143d463',
#                         [{"marker": {"color": "rgb(55, 83, 109)"}, "name": "Points", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [18.643774069319644, 19.978950307091054, 19.875082690187437, 19.787384615384646, 21.018857822724506]}, {"marker": {"color": "rgb(26, 118, 255)"}, "name": "Assists", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [2.403722721437746, 3.2458961474036814, 8.50192943770674, 3.6081230769230723, 4.446817370612729]}],
# ...

# %%
#testing color 
label = dfclust4['Pos2']
points = dfclust4['PTS']
assists = dfclust4['AST']
fig = go.Figure()
fig.add_trace(go.Bar(x=label,
                y= points,
                name='Points',
                marker_color='rgb(55, 83, 109)'
                ))
fig.add_trace(go.Bar(x=label,
                y=assists,
                name='Assists',
                marker_color='rgb(12, 200, 400)'
                ))

fig.update_layout(
    title='Points and Assists',
    xaxis_tickfont_size= 10,
    yaxis=dict(
        title='Count',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="bb7a9631-7090-4bf6-a4c0-d5e4329be2c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb7a9631-7090-4bf6-a4c0-d5e4329be2c0")) {
#                     Plotly.newPlot(
#                         'bb7a9631-7090-4bf6-a4c0-d5e4329be2c0',
#                         [{"marker": {"color": "rgb(55, 83, 109)"}, "name": "Points", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [18.643774069319644, 19.978950307091054, 19.875082690187437, 19.787384615384646, 21.018857822724506]}, {"marker": {"color": "rgb(12, 200, 400)"}, "name": "Assists", "type": "bar", "x": ["C", "PF", "PG", "SF", "SG"], "y": [2.403722721437746, 3.2458961474036814, 8.50192943770674, 3.6081230769230723, 4.446817370612729]}],
# ...

# %%
dfclust4.columns
# Out:
# Index(['Pos2', 'DRtg', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Age', 'G', 'GS',
#        'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB',
#        'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%',
#        'eFG%', 'FT%', 'TS%', 'Year', 'Cluster'],
#       dtype='object')

# %%
label = dfclust4['Pos2']
points = dfclust4['PTS']
assists = dfclust4['AST']
rebounds = dfclust4['TRB']
threept = dfclust4['3P%']
blocks = dfclust4['BLK']
steals = dfclust4['STL']
fig = go.Figure()
fig.add_trace(go.Bar(x=label,
                y= points,
                name='Points',
                marker_color='rgb(55, 83, 109)'
                ))
fig.add_trace(go.Bar(x=label,
                y=assists,
                name='Assists',
                marker_color='rgb(26, 118, 255)'
                ))
fig.add_trace(go.Bar(x=label,
                y=rebounds,
                name='rebounds',
                marker_color='rgb(100, 50, 300)'
                ))
fig.add_trace(go.Bar(x=label,
                y=threept,
                name='threept',
                marker_color='rgb(4, 40, 60)'
                ))
fig.add_trace(go.Bar(x=label,
                y=blocks,
                name='blocks',
                marker_color='rgb(150, 160, 200)'
                ))
fig.add_trace(go.Bar(x=label,
                y=steals,
                name='steals',
                marker_color='rgb(40, 250, 100)'
                ))
fig.update_layout(
    title='BoxScore Stats',
    xaxis_tickfont_size= 10,
    yaxis=dict(
        title='Average',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="322e9c6b-be3b-41ac-bb5a-df2f596ff4d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("322e9c6b-be3b-41ac-bb5a-df2f596ff4d6")) {
#                     Plotly.newPlot(
#                         '322e9c6b-be3b-41ac-bb5a-df2f596ff4d6',
# ...

# %%
dfclust2=dfclust.groupby('Pos2').mean()

# %%
dfclusterf3=dfclusterf2.groupby('Pos').mean()

# %%
dfclusterf3.head()
# Out:
#            DRtg        ORtg       USG%      VORP        WS        PER  \
# Pos
# C    104.742814  111.062027  18.210893  1.017549  3.868230  16.722542
# PF   106.682128  107.283765  18.733834  0.712142  3.288404  14.499045
# PG   109.239102  104.573316  20.502642  0.697226  2.855746  13.919419
# SF   108.013294  105.314623  17.694535  0.708272  2.823191  12.376957
# SG   109.416877  104.426952  19.732242  0.442821  2.498489  12.563602
#
#            Age          G         GS           MP  ...        PF        PTS  \
# Pos                                                ...
# C    26.789713  62.048411  33.142209  1359.895613  ...  5.733585  20.060061
# PF   26.654843  63.510232  29.885402  1467.327422  ...  4.891814  20.200000
# PG   26.726552  60.681638  29.034346  1485.879789  ...  3.886262  20.504359
# SF   26.862629  63.515510  32.181684  1543.719350  ...  4.010635  18.964254
# SG   26.746851  62.856423  28.278338  1528.515113  ...  3.748992  21.014861
#
# ...

# %%
dfclusterf3.reset_index(inplace=True)

# %%
dfclusterf3.head()
# Out:
#   Pos        DRtg        ORtg       USG%      VORP        WS        PER  \
# 0   C  104.742814  111.062027  18.210893  1.017549  3.868230  16.722542
# 1  PF  106.682128  107.283765  18.733834  0.712142  3.288404  14.499045
# 2  PG  109.239102  104.573316  20.502642  0.697226  2.855746  13.919419
# 3  SF  108.013294  105.314623  17.694535  0.708272  2.823191  12.376957
# 4  SG  109.416877  104.426952  19.732242  0.442821  2.498489  12.563602
#
#          Age          G         GS  ...        PF        PTS       FG%  \
# 0  26.789713  62.048411  33.142209  ...  5.733585  20.060061  0.524939
# 1  26.654843  63.510232  29.885402  ...  4.891814  20.200000  0.465010
# 2  26.726552  60.681638  29.034346  ...  3.886262  20.504359  0.419400
# 3  26.862629  63.515510  32.181684  ...  4.010635  18.964254  0.429445
# 4  26.746851  62.856423  28.278338  ...  3.748992  21.014861  0.420992
#
#         2P%       3P%      eFG%       FT%       TS%         Year   Cluster
# ...

# %% [markdown]
# ### checkpt1

# %%
Pos.value_counts()

# %%
dfclusterz=pd.read_csv('newcorrectfinaldatalastlast.csv')

# %%
dfclusterz.Pos.value_counts()
# Out:
# SG       782
# PG       751
# PF       726
# SF       670
# C        659
# SG-PG      6
# PG-SG      6
# SG-SF      5
# SF-SG      5
# PF-SF      5
# C-PF       2
# PF-C       2
# SF-PF      2
# SG-PF      1
# Name: Pos, dtype: int64

# %%
dfclusterz.Pos.value_counts()
# Out:
# SG    794
# PG    757
# PF    733
# SF    677
# C     661
# Name: Pos, dtype: int64

# %%
dfclusterz.to_csv('dfRolezzz.csv', index=False)

# %%
dfclustz=dfclusterz.groupby('Pos').mean()

# %%
dfclustz.reset_index(inplace=True)

# %%
dfclustzzz=dfclustz

# %%
dfclustzzz.to_csv('dfclustzzz.csv', index=False)

# %%
label = dfclustz['Pos']
points = dfclustz['PTS']
assists = dfclustz['AST']
rebounds = dfclustz['TRB']
threept = dfclustz['3P%']
blocks = dfclustz['BLK']
steals = dfclustz['STL']
fig = go.Figure()
fig.add_trace(go.Bar(x=label,
                y= points,
                name='Points',
                marker_color='rgb(55, 83, 109)'
                ))
fig.add_trace(go.Bar(x=label,
                y=assists,
                name='Assists',
                marker_color='rgb(26, 118, 255)'
                ))
fig.add_trace(go.Bar(x=label,
                y=rebounds,
                name='rebounds',
                marker_color='rgb(100, 50, 300)'
                ))
fig.add_trace(go.Bar(x=label,
                y=threept,
                name='threept',
                marker_color='rgb(400, 5, 60)'
                ))
fig.add_trace(go.Bar(x=label,
                y=blocks,
                name='blocks',
                marker_color='rgb(150, 160, 200)'
                ))
fig.add_trace(go.Bar(x=label,
                y=steals,
                name='steals',
                marker_color='rgb(40, 250, 100)'
                ))
fig.update_layout(
    title='BoxScore Stats',
    xaxis_tickfont_size= 10,
    yaxis=dict(
        title='Average',
        titlefont_size=16,
        tickfont_size=14,
    ),
    xaxis=dict(
        title='Positions'
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# fig.write_image("boxscorepositions.png")
# Out:
# <div>
#
#
#             <div id="75bdd299-e870-42e6-addb-57780b733417" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("75bdd299-e870-42e6-addb-57780b733417")) {
#                     Plotly.newPlot(
#                         '75bdd299-e870-42e6-addb-57780b733417',
# ...

# %%
dfclust.head()
# Out:
#               Player  DRtg   Season   ORtg  USG%  VORP   WS   PER   Age   Tm  \
# 0       Álex Abrines   111  2018-19  103.0  12.2  -0.2  0.6   6.3  25.0  OKC
# 1       Jaylen Adams   115  2018-19   99.0  13.5  -0.3  0.1   7.6  22.0  ATL
# 2       Steven Adams   106  2018-19  120.0  16.4   3.2  9.1  18.5  25.0  OKC
# 3        Bam Adebayo   104  2018-19  120.0  15.8   2.4  6.8  17.9  21.0  MIA
# 4  LaMarcus Aldridge   110  2018-19  117.0  26.9   2.5  9.3  22.9  33.0  SAS
#
#    ...    2P%    3P%   eFG%    FT%    TS%  Year  Pos  Cluster  \
# 0  ...  0.500  0.323  0.487  0.923  0.507  2018   SG      5.0
# 1  ...  0.361  0.338  0.459  0.778  0.474  2018   PG      5.0
# 2  ...  0.596  0.000  0.595  0.500  0.591  2018    C      6.0
# 3  ...  0.588  0.200  0.579  0.735  0.623  2018    C      6.0
# 4  ...  0.528  0.238  0.522  0.847  0.576  2018    C      6.0
#
#                Role  Pos2
# 0  Perimeter Scorer    SG
# 1  Perimeter Scorer    PG
# 2   Star Inside Big     C
# ...

# %%
dfclusterf2.head()
# Out:
#               Player  DRtg   Season   ORtg  USG%  VORP   WS   PER   Age   Tm  \
# 0       Álex Abrines   111  2018-19  103.0  12.2  -0.2  0.6   6.3  25.0  OKC
# 1       Jaylen Adams   115  2018-19   99.0  13.5  -0.3  0.1   7.6  22.0  ATL
# 2       Steven Adams   106  2018-19  120.0  16.4   3.2  9.1  18.5  25.0  OKC
# 3        Bam Adebayo   104  2018-19  120.0  15.8   2.4  6.8  17.9  21.0  MIA
# 4  LaMarcus Aldridge   110  2018-19  117.0  26.9   2.5  9.3  22.9  33.0  SAS
#
#    ...    FG%    2P%    3P%   eFG%    FT%    TS%  Year  Pos  Cluster  \
# 0  ...  0.357  0.500  0.323  0.487  0.923  0.507  2018   SG        5
# 1  ...  0.345  0.361  0.338  0.459  0.778  0.474  2018   PG        5
# 2  ...  0.595  0.596  0.000  0.595  0.500  0.591  2018    C        6
# 3  ...  0.576  0.588  0.200  0.579  0.735  0.623  2018    C        6
# 4  ...  0.519  0.528  0.238  0.522  0.847  0.576  2018    C        6
#
#                Role
# 0  Perimeter Scorer
# 1  Perimeter Scorer
# 2   Star Inside Big
# ...

# %%
dfclustzr=dfclusterz.groupby('Role').mean()

# %%
dfclustzr.reset_index(inplace=True)

# %%
dfclustRole=dfclusterf2.groupby('Role').mean()

# %%
dfclustRole.reset_index(inplace=True)

# %%
label = dfclustzr['Role']
points = dfclustzr['PTS']
assists = dfclustzr['AST']
rebounds = dfclustzr['TRB']
threept = dfclustzr['3P%']
blocks = dfclustzr['BLK']
steals = dfclustzr['STL']
fig = go.Figure()
fig.add_trace(go.Bar(x=label,
                y= points,
                name='Points',
                marker_color='rgb(55, 83, 109)'
                ))
fig.add_trace(go.Bar(x=label,
                y=assists,
                name='Assists',
                marker_color='rgb(26, 118, 255)'
                ))
fig.add_trace(go.Bar(x=label,
                y=rebounds,
                name='rebounds',
                marker_color='rgb(100, 50, 300)'
                ))
fig.add_trace(go.Bar(x=label,
                y=threept,
                name='threept',
                marker_color='rgb(400, 5, 60)'
                ))
fig.add_trace(go.Bar(x=label,
                y=blocks,
                name='blocks',
                marker_color='rgb(150, 160, 200)'
                ))
fig.add_trace(go.Bar(x=label,
                y=steals,
                name='steals',
                marker_color='rgb(40, 250, 100)'
                ))
fig.update_layout(
    title='BoxScore Stats',
    xaxis_tickfont_size= 10,
    yaxis=dict(
        title='Average',
        titlefont_size=16,
        tickfont_size=14,
    ),
    xaxis=dict(
        title='Role'
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="e44dd8b3-337a-4a7d-9fce-7591b3e4527f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e44dd8b3-337a-4a7d-9fce-7591b3e4527f")) {
#                     Plotly.newPlot(
#                         'e44dd8b3-337a-4a7d-9fce-7591b3e4527f',
# ...

# %%
dfclust.columns
# Out:
# Index(['Player', 'DRtg', 'Season', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Age',
#        'Tm', 'Lg', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA',
#        'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%', 'Year', 'Pos',
#        'Cluster', 'Role', 'Pos2'],
#       dtype='object')

# %%
# cluster 3d new roles will need pca version?

# %%
fig = px.scatter_3d(dfclusterf2, x='DRtg', y='PTS', z='ORtg', color='Pos',
              )
fig.show()
# Out:
# <div>
#
#
#             <div id="c7a085f2-9cd5-4b0e-9e1c-98ad00cc676e" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c7a085f2-9cd5-4b0e-9e1c-98ad00cc676e")) {
#                     Plotly.newPlot(
#                         'c7a085f2-9cd5-4b0e-9e1c-98ad00cc676e',
# ...

# %%
dfclusterdropped=dfclusterf2.dropna()

# %%
dfclustpca6=pd.read_csv('PCAdata6.csv')

# %%
dfclustpca6.head()
# Out:
#               Player  DRtg   Season   ORtg  USG%  VORP   WS   PER   Age   Tm  \
# 0       Álex Abrines   111  2018-19  103.0  12.2  -0.2  0.6   6.3  25.0  OKC
# 1       Jaylen Adams   115  2018-19   99.0  13.5  -0.3  0.1   7.6  22.0  ATL
# 2       Steven Adams   106  2018-19  120.0  16.4   3.2  9.1  18.5  25.0  OKC
# 3        Bam Adebayo   104  2018-19  120.0  15.8   2.4  6.8  17.9  21.0  MIA
# 4  LaMarcus Aldridge   110  2018-19  117.0  26.9   2.5  9.3  22.9  33.0  SAS
#
#    ...   eFG%    FT%    TS%  Year  Pos  Cluster              Role       PC1  \
# 0  ...  0.487  0.923  0.507  2018   SG        5  Perimeter Scorer -5.593891
# 1  ...  0.459  0.778  0.474  2018   PG        5  Perimeter Scorer -5.728519
# 2  ...  0.595  0.500  0.591  2018    C        6   Star Inside Big  4.483631
# 3  ...  0.579  0.735  0.623  2018    C        6   Star Inside Big  4.051124
# 4  ...  0.522  0.847  0.576  2018    C        6   Star Inside Big  6.805887
#
#         PC2       PC3
# 0 -0.233216  2.459505
# ...

# %%
dfclustpca6.to_csv('dfclustpca6.csv', index=False)

# %%
fig = px.scatter_3d(dfclustpca6, x='PC1', y='PC2', z='PC3', color='Role',
              )
fig.show()
# Out:
# <div>
#
#
#             <div id="2ef5e74a-2983-4896-8e7d-1b054d11cc36" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2ef5e74a-2983-4896-8e7d-1b054d11cc36")) {
#                     Plotly.newPlot(
#                         '2ef5e74a-2983-4896-8e7d-1b054d11cc36',
# ...

# %%
dfclusterf2.isnull().sum()
# Out:
# Player       0
# DRtg         0
# Season       0
# ORtg         0
# USG%         0
# VORP         0
# WS           0
# PER          0
# Age          0
# Tm           0
# Lg           0
# G            0
# GS           0
# MP           0
# FG           0
# FGA          0
# 2P           0
# 2PA          0
# 3P           0
# 3PA          0
# FT           0
# FTA          0
# ORB          0
# DRB          0
# TRB          0
# AST          0
# STL          0
# BLK          0
# TOV          0
# PF           0
# PTS          0
# FG%          0
# 2P%          0
# 3P%          0
# eFG%         0
# FT%          0
# TS%          0
# Year         0
# Pos          0
# Cluster      0
# Role       277
# dtype: int64

# %%
dfPCA=pd.read_csv('PCAdata.csv')

# %%
len(dfPCA)
# Out:
# 3622

# %%
dfPCA.isnull().sum()
# Out:
# Player       0
# DRtg         0
# Season       0
# ORtg         0
# USG%         0
# VORP         0
# WS           0
# PER          0
# Age          0
# Tm           0
# Lg           0
# G            0
# GS           0
# MP           0
# FG           0
# FGA          0
# 2P           0
# 2PA          0
# 3P           0
# 3PA          0
# FT           0
# FTA          0
# ORB          0
# DRB          0
# TRB          0
# AST          0
# STL          0
# BLK          0
# TOV          0
# PF           0
# PTS          0
# FG%          0
# 2P%          0
# 3P%          0
# eFG%         0
# FT%          0
# TS%          0
# Year         0
# Pos          0
# Cluster      0
# Role       277
# PC1          0
# PC2          0
# PC3          0
# dtype: int64

# %%
dfPCA2=dfPCA.dropna()

# %%
# cluster 3d old position (will need to PCA as well?)

# %%
from sklearn.decomposition import PCA

# %%
pca_list = []

for n_components in range(2, 11):
    pca = PCA(n_components = n_components)
    components = pca.fit_transform(X_scaled)
    pca_variance = sum(pca.explained_variance_ratio_)
    pca_list.append(pca_variance)
    print("For n_components = {}, explained variance ratio is {}".format(n_components, pca_variance))

# %%
from sklearn.preprocessing import StandardScaler

# %%
dfmod2=pd.read_csv('dfmodd2.csv')

# %%
dfmod2.head()
# Out:
#               Player  DRtg   Season   ORtg  USG%  VORP   WS   PER   Rk   Age  \
# 0       Álex Abrines   111  2018-19  103.0  12.2  -0.2  0.6   6.3  1.0  25.0
# 1       Jaylen Adams   115  2018-19   99.0  13.5  -0.3  0.1   7.6  3.0  22.0
# 2       Steven Adams   106  2018-19  120.0  16.4   3.2  9.1  18.5  4.0  25.0
# 3        Bam Adebayo   104  2018-19  120.0  15.8   2.4  6.8  17.9  5.0  21.0
# 4  LaMarcus Aldridge   110  2018-19  117.0  26.9   2.5  9.3  22.9  8.0  33.0
#
#    ...   PF   PTS    FG%    2P%    3P%   eFG%    FT%    TS%  Year  Pos
# 0  ...  4.2  13.1  0.357  0.500  0.323  0.487  0.923  0.507  2018   SG
# 1  ...  4.9  11.7  0.345  0.361  0.338  0.459  0.778  0.474  2018   PG
# 2  ...  3.6  19.4  0.595  0.596  0.000  0.595  0.500  0.591  2018    C
# 3  ...  5.2  18.6  0.576  0.588  0.200  0.579  0.735  0.623  2018    C
# 4  ...  3.3  31.4  0.519  0.528  0.238  0.522  0.847  0.576  2018    C
#
# [5 rows x 40 columns]

# %%
dfmod2.columns
# Out:
# Index(['Player', 'DRtg', 'Season', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Rk',
#        'Age', 'Tm', 'Lg', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P',
#        '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF', 'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%', 'Year', 'Pos'],
#       dtype='object')

# %%
dfmod3=dfmod2.drop(['Player', 'Season', 'ORtg', 'DRtg', 'Rk', 'Age','Lg','G','GS','MP','Year','Pos','Tm' ], axis=1)

# %%
dfmod3.columns
# Out:
# Index(['USG%', 'VORP', 'WS', 'PER', 'FG', 'FGA', '2P', '2PA', '3P', '3PA',
#        'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%'],
#       dtype='object')

# %%
# get modern data with position still in 
# need to scale then pca for 3 ... 
# include only certain variables

# %%
Xs=dfmod3

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(Xs)

# %%
pca = PCA(n_components = 3)

components = pca.fit_transform(Xs)

pca_df = pd.DataFrame(data = components, columns = ['PC 1', 'PC 2', 'PC 3'])

pca_df['Player'] = dfmod2['Player']
pca_df = pca_df[['Player', 'PC 1', 'PC 2', 'PC 3']]

# %%
pca_df.head()
# Out:
#               Player       PC 1       PC 2      PC 3
# 0       Álex Abrines -17.837450  -7.977564  2.350659
# 1       Jaylen Adams -16.646420  -4.758677  0.875816
# 2       Steven Adams   1.630315   9.918647  3.156791
# 3        Bam Adebayo  -0.644113  11.170203  4.280102
# 4  LaMarcus Aldridge  23.492726   7.434075 -0.525795

# %%
pca_df['Pos'] = dfmod2['Pos']

# %%
pca_df.Pos.value_counts()
# Out:
# SG       782
# PG       751
# PF       726
# SF       670
# C        659
# SG-PG      6
# PG-SG      6
# SG-SF      5
# SF-SG      5
# PF-SF      5
# C-PF       2
# PF-C       2
# SF-PF      2
# SG-PF      1
# Name: Pos, dtype: int64

# %%
dfpospca=pca_df

# %%
dfpospca.Pos.value_counts()
# Out:
# SG       782
# PG       751
# PF       726
# SF       670
# C        659
# SG-PG      6
# PG-SG      6
# SG-SF      5
# SF-SG      5
# PF-SF      5
# C-PF       2
# PF-C       2
# SF-PF      2
# SG-PF      1
# Name: Pos, dtype: int64

# %%
dfpospca.loc[dfpospca.Pos=='SG-PG', ["Pos"]] = 'SG'

# %%
dfpospca.loc[dfpospca.Pos=='PG-SG', ["Pos"]] = 'PG'

# %%
dfpospca.loc[dfpospca.Pos=='SG-SF', ["Pos"]] = 'SG'

# %%
dfpospca.loc[dfpospca.Pos=='SF-SG', ["Pos"]] = 'SF'

# %%
dfpospca.loc[dfpospca.Pos=='PF-SF', ["Pos"]] = 'PF'

# %%
dfpospca.loc[dfpospca.Pos=='C-PF', ["Pos"]] = 'C'

# %%
dfpospca.loc[dfpospca.Pos=='PF-C', ["Pos"]] = 'PF'

# %%
dfpospca.loc[dfpospca.Pos=='SF-PF', ["Pos"]] = 'SF'

# %%
dfpospca.loc[dfpospca.Pos=='SG-PF', ["Pos"]] = 'SG'

# %%
dfpospca.Pos.value_counts()
# Out:
# SG    794
# PG    757
# PF    733
# SF    677
# C     661
# Name: Pos, dtype: int64

# %%
dfpospca.to_csv('dfpospcazzz.csv', index=False)

# %%
fig = px.scatter_3d(dfpospca, x='PC 1', y='PC 2', z='PC 3', color='Pos',
              )
fig.show()
# Out:
# <div>
#
#
#             <div id="c4be9c12-d2e2-46b8-a61c-a2e3e3162571" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c4be9c12-d2e2-46b8-a61c-a2e3e3162571")) {
#                     Plotly.newPlot(
#                         'c4be9c12-d2e2-46b8-a61c-a2e3e3162571',
# ...

# %%
dfPCA3=dfPCA2

# %%
dfPCA3.Pos.value_counts()
# Out:
# SG       780
# PG       748
# SF       667
# PF       641
# C        476
# SG-PG      6
# PG-SG      6
# SG-SF      5
# SF-SG      5
# PF-SF      5
# PF-C       2
# SF-PF      2
# C-PF       1
# SG-PF      1
# Name: Pos, dtype: int64

# %%
dfPCA3.loc[dfPCA3.Pos=='SG-PG', ["Pos"]] = 'SG'
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfPCA3.loc[dfPCA3.Pos=='PG-SG', ["Pos"]] = 'PG'

# %%
dfPCA3.loc[dfPCA3.Pos=='SG-SF', ["Pos"]] = 'SG'

# %%
dfPCA3.loc[dfPCA3.Pos=='SF-SG', ["Pos"]] = 'SF'

# %%
dfPCA3.loc[dfPCA3.Pos=='PF-SF', ["Pos"]] = 'PF'

# %%
dfPCA3.loc[dfPCA3.Pos=='PF-C', ["Pos"]] = 'PF'

# %%
dfPCA3.loc[dfPCA3.Pos=='SF-PF', ["Pos"]] = 'SF'

# %%
dfPCA3.loc[dfPCA3.Pos=='C-PF', ["Pos"]] = 'C'

# %%
dfPCA3.loc[dfPCA3.Pos=='SG-PF', ["Pos"]] = 'SG'

# %%
dfPCA3.Pos.value_counts()
# Out:
# SG    787
# PG    754
# SF    679
# PF    648
# C     477
# Name: Pos, dtype: int64

# %%
# pie chart value count of old positions

# %%
dfcountpos=dfclusterf['Pos'].value_counts()

# %%
dfcountpos.head()
# Out:
# PG    1814
# PF    1791
# SG    1681
# SF    1625
# C     1558
# Name: Pos, dtype: int64

# %% [markdown]
# ### PIE charts

# %%
labels = dfclusterz.Pos.unique()
values = dfclusterz['Pos'].value_counts(normalize=False)

fig = go.Figure(data =[go.Pie(labels=labels, values=values)])
fig.update_layout(
    title='Positions',
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="5aaaec1d-19d5-42c3-a69c-4d5015c19396" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5aaaec1d-19d5-42c3-a69c-4d5015c19396")) {
#                     Plotly.newPlot(
#                         '5aaaec1d-19d5-42c3-a69c-4d5015c19396',
#                         [{"labels": ["SG", "PG", "C", "PF", "SF"], "type": "pie", "values": [794, 757, 733, 677, 661]}],
# ...

# %%
labels = dfclusterz.Role.unique()
values = dfclusterz['Role'].value_counts(normalize=False)

fig = go.Figure(data =[go.Pie(labels=labels, values=values)])
fig.update_layout(
    title='Roles',
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="c42f46eb-8dc6-41d4-a141-e91720086428" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c42f46eb-8dc6-41d4-a141-e91720086428")) {
#                     Plotly.newPlot(
#                         'c42f46eb-8dc6-41d4-a141-e91720086428',
#                         [{"labels": ["Perimeter Scorer", "Star Inside Big", "Do It All", "Elite Wing", "3&D", "Superstar", "All Star", "Backup Inside Big", "Elite Inside Big"], "type": "pie", "values": [935, 573, 490, 444, 325, 306, 277, 170, 102]}],
# ...

# %%
dfclusterf.Pos.unique()
# Out:
# array(['SG', 'PG', 'C', 'PF', 'SF'], dtype=object)

# %%
# pie chart value count of new role

# %%
#Business insight stuff, does

# %%
# make dataframe of nba finalist roster 
# do value count of roles 
# create pie chart

# %%
dfclustpca6.head(300)
# Out:
#                      Player  DRtg   Season   ORtg  USG%  VORP    WS   PER  \
# 0              Álex Abrines   111  2018-19  103.0  12.2  -0.2   0.6   6.3
# 1              Jaylen Adams   115  2018-19   99.0  13.5  -0.3   0.1   7.6
# 2              Steven Adams   106  2018-19  120.0  16.4   3.2   9.1  18.5
# 3               Bam Adebayo   104  2018-19  120.0  15.8   2.4   6.8  17.9
# 4         LaMarcus Aldridge   110  2018-19  117.0  26.9   2.5   9.3  22.9
# 5             Grayson Allen   111  2018-19   95.0  24.4  -0.5   0.0   7.5
# 6             Jarrett Allen   106  2018-19  123.0  15.9   2.4   7.6  18.5
# 7              Kadeem Allen   114  2018-19  116.0  19.6   0.1   1.0  16.2
# 8           Al-Farouq Aminu   109  2018-19  118.0  13.7   1.7   5.8  13.2
# 9           Justin Anderson   113  2018-19  103.0  17.2  -0.1   0.4  11.2
# 10            Kyle Anderson   107  2018-19  110.0  12.6   1.0   2.7  12.8
# 11    Giannis Antetokounmpo    99  2018-19  121.0  32.3   7.6  14.4  30.9
# ...

# %%
len(dfclustpca6)
# Out:
# 3622

# %%
dfclustpca6[dfclustpca6['Tm'] == 'MIA']
# Out:
#                 Player  DRtg   Season   ORtg  USG%  VORP    WS   PER   Age  \
# 3          Bam Adebayo   104  2018-19  120.0  15.8   2.4   6.8  17.9  21.0
# 146       Goran Dragić   111  2018-19  106.0  23.7   0.2   1.6  13.9  32.0
# 257      James Johnson   108  2018-19  102.0  17.8   0.1   1.5  10.9  31.0
# 269      Derrick Jones   107  2018-19  113.0  15.6   0.6   2.9  14.0  21.0
# 340    Rodney McGruder   111  2018-19  104.0  15.4   0.0   1.9   9.4  27.0
# 390       Kelly Olynyk   108  2018-19  114.0  18.0   1.4   4.7  14.4  27.0
# 421    Josh Richardson   110  2018-19  111.0  20.9   1.7   5.6  14.0  25.0
# 490        Dwyane Wade   109  2018-19  102.0  27.9   0.7   2.4  15.8  37.0
# 492       Dion Waiters   111  2018-19  102.0  21.1   0.0   1.2  11.4  27.0
# 500   Hassan Whiteside    99  2018-19  112.0  22.6   1.2   6.3  23.5  29.0
# 506    Justise Winslow   108  2018-19  102.0  20.8   1.0   2.8  12.8  22.0
# ...

# %%
dfLeb=dfclustpca6[dfclustpca6['Player'] == 'LeBron James']

# %%
dfLeb.head()
# Out:
#             Player  DRtg   Season   ORtg  USG%  VORP    WS   PER   Age   Tm  \
# 254   LeBron James   108  2018-19  114.0  31.6   4.9   7.2  25.6  34.0  LAL
# 736   LeBron James   109  2017-18  118.0  31.6   8.9  14.0  28.6  33.0  CLE
# 1186  LeBron James   108  2016-17  119.0  30.0   7.3  12.9  27.0  32.0  CLE
# 1630  LeBron James   103  2015-16  116.0  31.4   7.6  13.6  27.5  31.0  CLE
# 2095  LeBron James   105  2014-15  112.0  32.3   5.9  10.4  25.9  30.0  CLE
#
#       ...   eFG%    FT%    TS%  Year  Pos  Cluster       Role       PC1  \
# 254   ...  0.560  0.665  0.588  2018   SF        4  Superstar  6.963591
# 736   ...  0.590  0.731  0.621  2017   PF        4  Superstar  9.019963
# 1186  ...  0.594  0.674  0.619  2016   SF        4  Superstar  8.370071
# 1630  ...  0.551  0.731  0.588  2015   SF        4  Superstar  8.826652
# 2095  ...  0.535  0.710  0.577  2014   SF        4  Superstar  7.279767
#
#            PC2       PC3
# 254   4.821767  0.786689
# ...

# %%
dfLeb[dfLeb['Year']>2013]
# Out:
#             Player  DRtg   Season   ORtg  USG%  VORP    WS   PER   Age   Tm  \
# 254   LeBron James   108  2018-19  114.0  31.6   4.9   7.2  25.6  34.0  LAL
# 736   LeBron James   109  2017-18  118.0  31.6   8.9  14.0  28.6  33.0  CLE
# 1186  LeBron James   108  2016-17  119.0  30.0   7.3  12.9  27.0  32.0  CLE
# 1630  LeBron James   103  2015-16  116.0  31.4   7.6  13.6  27.5  31.0  CLE
# 2095  LeBron James   105  2014-15  112.0  32.3   5.9  10.4  25.9  30.0  CLE
#
#       ...   eFG%    FT%    TS%  Year  Pos  Cluster       Role       PC1  \
# 254   ...  0.560  0.665  0.588  2018   SF        4  Superstar  6.963591
# 736   ...  0.590  0.731  0.621  2017   PF        4  Superstar  9.019963
# 1186  ...  0.594  0.674  0.619  2016   SF        4  Superstar  8.370071
# 1630  ...  0.551  0.731  0.588  2015   SF        4  Superstar  8.826652
# 2095  ...  0.535  0.710  0.577  2014   SF        4  Superstar  7.279767
#
#            PC2       PC3
# 254   4.821767  0.786689
# ...

# %%
dfKD=dfclustpca6[dfclustpca6['Player'] == 'Kevin Durant']

# %%
dfKD.head()
# Out:
#             Player  DRtg   Season   ORtg  USG%  VORP    WS   PER   Age   Tm  \
# 150   Kevin Durant   110  2018-19  121.0  29.0   4.3  11.5  24.2  30.0  GSW
# 641   Kevin Durant   107  2017-18  119.0  30.4   4.5  10.4  26.0  29.0  GSW
# 1088  Kevin Durant   101  2016-17  125.0  27.8   5.2  12.0  27.6  28.0  GSW
# 1533  Kevin Durant   104  2015-16  122.0  30.6   6.4  14.5  28.2  27.0  OKC
# 2003  Kevin Durant   105  2014-15  121.0  29.1   1.9   4.8  27.6  26.0  OKC
#
#       ...   eFG%    FT%    TS%  Year  Pos  Cluster       Role       PC1  \
# 150   ...  0.571  0.885  0.631  2018   SF        4  Superstar  6.905892
# 641   ...  0.586  0.889  0.640  2017   SF        4  Superstar  7.043921
# 1088  ...  0.594  0.875  0.651  2016   PF        4  Superstar  8.250789
# 1533  ...  0.573  0.898  0.634  2015   SF        4  Superstar  8.539690
# 2003  ...  0.578  0.854  0.633  2014   SF        8   All Star  6.341354
#
#            PC2       PC3
# 150   4.634836  2.574903
# ...

# %%
dfstack=pd.concat([dfLeb, dfKD])

# %%
len(dfLeb)
# Out:
# 8

# %%
len(dfKD)
# Out:
# 8

# %%
len(dfstack)
# Out:
# 16

# %%
dfstack.head()
# Out:
#             Player  DRtg   Season   ORtg  USG%  VORP    WS   PER   Age   Tm  \
# 254   LeBron James   108  2018-19  114.0  31.6   4.9   7.2  25.6  34.0  LAL
# 736   LeBron James   109  2017-18  118.0  31.6   8.9  14.0  28.6  33.0  CLE
# 1186  LeBron James   108  2016-17  119.0  30.0   7.3  12.9  27.0  32.0  CLE
# 1630  LeBron James   103  2015-16  116.0  31.4   7.6  13.6  27.5  31.0  CLE
# 2095  LeBron James   105  2014-15  112.0  32.3   5.9  10.4  25.9  30.0  CLE
#
#       ...   eFG%    FT%    TS%  Year  Pos  Cluster       Role       PC1  \
# 254   ...  0.560  0.665  0.588  2018   SF        4  Superstar  6.963591
# 736   ...  0.590  0.731  0.621  2017   PF        4  Superstar  9.019963
# 1186  ...  0.594  0.674  0.619  2016   SF        4  Superstar  8.370071
# 1630  ...  0.551  0.731  0.588  2015   SF        4  Superstar  8.826652
# 2095  ...  0.535  0.710  0.577  2014   SF        4  Superstar  7.279767
#
#            PC2       PC3
# 254   4.821767  0.786689
# ...

# %%
df1=dfclustpca6

# %%
dfCB=df1[df1['Player']=='Chris Bosh']

# %%
dfclustpca6[dfclustpca6['Player'] == 'Kevin Durant']

# %%
len(dfCB)
# Out:
# 5

# %%
dfstack=pd.concat([dfLeb, dfKD, dfCB])

# %%
len(dfstack)
# Out:
# 21

# %%
df1[df1['Player']=='Chris Bosh']

# %%
df2=df1[df1['Year']>2015]

# %%
#only going to do last 3 finals

# %%
df1[df1['Player']=='Kawhi Leonard']
# Out:
#              Player  DRtg   Season   ORtg  USG%  VORP    WS   PER   Age   Tm  \
# 302   Kawhi Leonard   105  2018-19  119.0  30.3   3.6   9.5  25.8  27.0  TOR
# 1227  Kawhi Leonard   102  2016-17  121.0  31.1   6.2  13.6  27.6  25.0  SAS
# 1679  Kawhi Leonard    96  2015-16  121.0  25.8   6.2  13.7  26.0  24.0  SAS
# 2137  Kawhi Leonard    96  2014-15  113.0  23.0   4.1   8.6  22.0  23.0  SAS
# 2611  Kawhi Leonard    98  2013-14  116.0  18.3   3.8   7.7  19.4  22.0  SAS
# 3038  Kawhi Leonard    99  2012-13  114.0  16.4   2.7   6.2  16.4  21.0  SAS
# 3450  Kawhi Leonard   101  2011-12  119.0  14.5   2.4   5.5  16.6  20.0  SAS
#
#       ...   eFG%    FT%    TS%  Year  Pos  Cluster       Role       PC1  \
# 302   ...  0.546  0.854  0.606  2018   SF        4  Superstar  6.922283
# 1227  ...  0.541  0.880  0.610  2016   SF        4  Superstar  7.994568
# 1679  ...  0.565  0.874  0.616  2015   SF        4  Superstar  6.810887
# ...

# %%
dfKD=df2[df2['Player']=='Kevin Durant']

# %%
dfKD.head()
# Out:
#             Player  DRtg   Season   ORtg  USG%  VORP    WS   PER   Age   Tm  \
# 150   Kevin Durant   110  2018-19  121.0  29.0   4.3  11.5  24.2  30.0  GSW
# 641   Kevin Durant   107  2017-18  119.0  30.4   4.5  10.4  26.0  29.0  GSW
# 1088  Kevin Durant   101  2016-17  125.0  27.8   5.2  12.0  27.6  28.0  GSW
#
#       ...   eFG%    FT%    TS%  Year  Pos  Cluster       Role       PC1  \
# 150   ...  0.571  0.885  0.631  2018   SF        4  Superstar  6.905892
# 641   ...  0.586  0.889  0.640  2017   SF        4  Superstar  7.043921
# 1088  ...  0.594  0.875  0.651  2016   PF        4  Superstar  8.250789
#
#            PC2       PC3
# 150   4.634836  2.574903
# 641   4.857145  2.687378
# 1088  3.553463  3.188979
#
# [3 rows x 44 columns]

# %%
dfSC=df2[df2['Player']=='Stephen Curry']

# %%
dfKT=df2[df2['Player']=='Klay Thompson']

# %%
dfDG=df2[df2['Player']=='Draymond Green']

# %%
dfAI=df2[df2['Player']=='Andre Iguodala']

# %%
dfSL=df2[df2['Player']=='Shaun Livingston']

# %%
dfJMall=df2[df2['Player']=='JaVale McGee']

# %%
dfJM=dfJMall[dfJMall['Year']==2017]

# %%
dfJBall=df2[df2['Player']=='Jordan Bell']

# %%
dfJB=dfJBall[dfJBall['Year']==2017]

# %%
dfQCall=df2[df2['Player']=='Quinn Cook']

# %%
dfQC=dfQCall[dfQCall['Year']==2018]

# %%
dfDCall=df2[df2['Player']=='DeMarcus Cousins']

# %%
dfDC=dfDCall[dfDCall['Year']==2018]

# %%
dfKLall=df2[df2['Player']=='Kevon Looney']

# %%
dfKL=dfKLall[dfKLall['Year']==2018]

# %%
dfWestFinal=pd.concat([dfSC, dfKT, dfDG, dfAI, dfSL, dfJM, dfJB, dfQC, dfDC, dfKL])

# %%
dfstack=pd.concat([dfLeb, dfKD, dfCB])

# %%
# now do east finals

# %%
dfLJall=df2[df2['Player']=='LeBron James']

# %%
dfLJ=dfLJall[dfLJall['Year']<2018]

# %%
dfKIall=df2[df2['Player']=='Kyrie Irving']

# %%
dfKI=dfKIall[dfKIall['Year']==2016]

# %%
dfKLall=df2[df2['Player']=='Kevin Love']

# %%
dfKL=dfKLall[dfKLall['Year']<2018]

# %%
dfRJ=df2[df2['Player']=='Richard Jefferson']

# %%
dfJR=df2[df2['Player']=='J.R. Smith']

# %%
dfTTall=df2[df2['Player']=='Tristan Thompson']

# %%
dfTT=dfTTall[dfTTall['Year']<2018]

# %%
dfKKall=df2[df2['Player']=='Kyle Korver']

# %%
dfKK=dfKKall[dfKKall['Year']==2017]

# %%
dfClev=pd.concat([dfLJ, dfKI, dfKL, dfRJ, dfJR, dfTT, dfKK])

# %%
#now toronto

# %%
dfKL2=df2.query('Player == "Kawhi Leonard" and Year==2018')

# %%
dfPS=df2.query('Player == "Pascal Siakam" and Year==2018')

# %%
dfKL=df2.query('Player == "Kyle Lowry" and Year==2018')

# %%
dfFV=df2.query('Player == "Fred VanVleet" and Year==2018')

# %%
dfMGall=df2.query('Player == "Marc Gasol" and Year==2018')

# %%
dfMG=dfMGall.head(1)

# %%
dfMG.head()
# Out:
#          Player  DRtg   Season   ORtg  USG%  VORP   WS   PER   Age   Tm  ...  \
# 177  Marc Gasol   105  2018-19  108.0  20.7   3.0  6.0  16.7  34.0  TOT  ...
#
#       eFG%    FT%    TS%  Year  Pos  Cluster      Role      PC1       PC2  \
# 177  0.505  0.759  0.546  2018    C        8  All Star  1.79604  0.455264
#
#           PC3
# 177  0.596658
#
# [1 rows x 44 columns]

# %%
dfSI=df2.query('Player == "Serge Ibaka" and Year==2018')

# %%
dfDG=df2.query('Player == "Danny Green" and Year==2018')

# %%
dfNP=df2.query('Player == "Norman Powell" and Year==2018')

# %%
dfToronto=pd.concat([dfKL, dfPS, dfKL2, dfFV, dfMG, dfSI, dfDG, dfNP])

# %%
dfEastFinal=pd.concat([dfClev, dfToronto])

# %%
dfFinals=pd.concat([dfWestFinal, dfEastFinal])

# %%
dfFinals.to_csv('NBAfinalsdata.csv', index=False)

# %%
#now get average teams data...

# %%
dfKCP=df2.query('Player == "Kentavious Caldwell-Pope" and Year==2016')

# %%
dfMMorris=df2.query('Player == "Marcus Morris" and Year==2016')

# %%
dfTHarris=df2.query('Player == "Tobias Harris" and Year==2016')

# %%
dfADrum=df2.query('Player == "Andre Drummond" and Year==2016')

# %%
dfRJack=df2.query('Player == "Reggie Jackson" and Year==2016')

# %%
dfIsh=df2.query('Player == "Ish Smith" and Year==2016')

# %%
dfDet2016=pd.concat([dfKCP, dfMMorris, dfTHarris, dfADrum, dfRJack, dfIsh])

# %%
dfDeMarc=df2.query('Player == "DeMarcus Cousins" and Year==2016').head(1)

# %%
dfRGay=df2.query('Player == "Rudy Gay" and Year==2016')

# %%
dfDColl=df2.query('Player == "Darren Collison" and Year==2016')

# %%
dfAff=df2.query('Player == "Arron Afflalo" and Year==2016')

# %%
dfTemp=df2.query('Player == "Garrett Temple" and Year==2016')

# %%
dfBuddy=df2.query('Player == "Buddy Hield" and Year==2016').head(1)

# %%
dfKing2016=pd.concat([dfDeMarc, dfRGay, dfDColl, dfAff, dfTemp, dfBuddy])

# %%
df2016a=pd.concat([dfDet2016, dfKing2016])

# %%
dfWalker=df2.query('Player == "Kemba Walker" and Year==2017')

# %%
dfBatum=df2.query('Player == "Nicolas Batum" and Year==2017')

# %%
dfDHow=df2.query('Player == "Dwight Howard" and Year==2017')

# %%
dfMarv=df2.query('Player == "Marvin Williams" and Year==2017')

# %%
dfMKG=df2.query('Player == "Michael Kidd-Gilchrist" and Year==2017')

# %%
dfLamb=df2.query('Player == "Jeremy Lamb" and Year==2017')

# %%
dfHornets2017=pd.concat([dfWalker, dfBatum, dfDHow, dfMarv, dfMKG, dfLamb])

# %%
dfBGriff=df2.query('Player == "Blake Griffin" and Year==2017').head(1)

# %%
dfToby=df2.query('Player == "Tobias Harris" and Year==2017').head(1)

# %%
dfRiv=df2.query('Player == "Austin Rivers" and Year==2017')

# %%
dfLou=df2.query('Player == "Lou Williams" and Year==2017')

# %%
dfGall=df2.query('Player == "Danilo Gallinari" and Year==2017')

# %%
dfDeAnd=df2.query('Player == "DeAndre Jordan" and Year==2017')

# %%
dfClippers2017=pd.concat([dfBGriff, dfToby, dfRiv, dfLou, dfGall, dfDeAnd])

# %%
df2017a=pd.concat([dfHornets2017, dfClippers2017])

# %%
dfKemba=df2.query('Player == "Kemba Walker" and Year==2018')

# %%
dfNic=df2.query('Player == "Nicolas Batum" and Year==2018')

# %%
dfJer=df2.query('Player == "Jeremy Lamb" and Year==2018')

# %%
dfMarvy=df2.query('Player == "Marvin Williams" and Year==2018')

# %%
dfCody=df2.query('Player == "Cody Zeller" and Year==2018')

# %%
dfMiles=df2.query('Player == "Miles Bridges" and Year==2018')

# %%
dfHornets2018=pd.concat([dfKemba, dfNic, dfJer, dfMarvy, dfCody, dfMiles])

# %%
dfBarnes=df2.query('Player == "Harrison Barnes" and Year==2018').head(1)

# %%
dfBuddy=df2.query('Player == "Buddy Hield" and Year==2018')

# %%
df2.columns
# Out:
# Index(['Player', 'DRtg', 'Season', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Age',
#        'Tm', 'Lg', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA',
#        'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%', 'Year', 'Pos',
#        'Cluster', 'Role', 'PC1', 'PC2', 'PC3'],
#       dtype='object')

# %%
dfKings2018=df2.query('Tm == "SAC" and Year==2018').head(8)

# %%
df2018=pd.concat([dfHornets2018, dfKings2018])

# %%
dfAverage=pd.concat([df2016a, df2017a, df2018])

# %%
dfAverage.to_csv('dfAverage.csv', index=False)

# %%
dfFinals.columns
# Out:
# Index(['Player', 'DRtg', 'Season', 'ORtg', 'USG%', 'VORP', 'WS', 'PER', 'Age',
#        'Tm', 'Lg', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA',
#        'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%', 'Year', 'Pos',
#        'Cluster', 'Role', 'PC1', 'PC2', 'PC3'],
#       dtype='object')

# %% [markdown]
# ### END!

# %%
dfFinals.to_csv('dfFinalsss.csv', index=False)

# %%
labels = dfFinals.Role.unique()
values = dfFinals['Role'].value_counts(normalize=False)

fig = go.Figure(data =[go.Pie(labels=labels, values=values)])
fig.update_layout(
    title='Roles for Elite Teams',
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="75728498-57c7-4d53-8174-4f71fcbf7831" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("75728498-57c7-4d53-8174-4f71fcbf7831")) {
#                     Plotly.newPlot(
#                         '75728498-57c7-4d53-8174-4f71fcbf7831',
#                         [{"labels": ["Superstar", "All Star", "Elite Wing", "3&D", "Backup Inside Big", "Elite Inside Big", "Do It All", "Perimeter Scorer"], "type": "pie", "values": [11, 7, 6, 4, 4, 3, 3, 1]}],
# ...

# %%
dfAverage.to_csv('dfAverageee.csv', index=False)

# %%
labels = dfAverage.Role.unique()
values = dfAverage['Role'].value_counts(normalize=False)

fig = go.Figure(data =[go.Pie(labels=labels, values=values)])
fig.update_layout(
    title='Roles for Average Teams',
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <div>
#
#
#             <div id="9ee56f75-2b67-4cee-8d7b-c682b25eae50" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9ee56f75-2b67-4cee-8d7b-c682b25eae50")) {
#                     Plotly.newPlot(
#                         '9ee56f75-2b67-4cee-8d7b-c682b25eae50',
#                         [{"labels": ["Elite Wing", "All Star", "Star Inside Big", "Do It All", "Superstar", "Perimeter Scorer", "3&D", "Backup Inside Big"], "type": "pie", "values": [11, 9, 6, 5, 3, 2, 1, 1]}],
# ...
